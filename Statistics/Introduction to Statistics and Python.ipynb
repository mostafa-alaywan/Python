# %% [markdown]
# # <center><font size=10, color="blue"><u>Introduction to Statistics

# %% [markdown]
# - The field of statistics is concerned with collecting, analyzing, interpreting, and presenting data.
#
# - Using the statistical methods we can better understanding of the world around us , Make decisions and make predictions about the future using data.
#
# ### <u>1 - Samples & Populations
#
# - We often have questions concerning large populations. Gathering information from the entire population is not always possible due to barriers such as time, accessibility, or cost. Instead of gathering information from the whole population, we often gather information from a smaller subset of the population, known as a sample.
#
# - Values concerning a sample are referred to as sample statistics(e.g., sample mean) while values concerning a population(e.g., population mean) are referred to as population parameters.
#
# ### <u>2 - Representative Sample
# - When we collect a sample from a population, we ideally want the sample to be like a “mini version” of our population.
#
# >For example, suppose we want to understand the movie preferences of students in a certain school that has a population of 5,000 total students. Since it would take too long to survey every individual student, we might instead take a sample of 100 students and ask them about their preferences.
# If the overall student population is composed of 50% girls and 50% boys, our sample would not be representative if it included 90% boys and only 10% girls.
# ![rep_sample1.jpg](attachment:rep_sample1.jpg)

# %% [markdown]
# ### <u>3 - How to Obtain Sample ?
# - **Simple random sampling:** Randomly select individuals through the use of a random number generator or some means of random selection.
#
# - **systematic random sampling:** Put every member of a population into some order. Choose a random starting point and select every nth member to be in the sample.
#
# - **Stratified random sampling:** Split a population into groups. Randomly select some members from each group to be in the sample.
#
# ![stratified-sample.svg](attachment:stratified-sample.svg)
#
# >Example : An advertising firm, want to choose 40 households from a population of 310 households distributed in the towns A , B and C.
# There are 155 households in town A, 62 in town B and 93 in C.
# The firm decides to select a stratified sample of  20 households from Town A, 8 households from Town B and 12 households from C.

# %% [markdown]
# ### <u>4 - There are two main branches in the field of statistics:
#
#  - **Descriptive Statistics**
#  - **Inferential Statistics**
#
# ### <u>5 - Descriptive Statistics aims to describe a chunk of raw data using :
#
#  - **summary statistics :** mean , median , mode , etc , ...
#  - **graphs :** Boxplots , Barplot , Scatterplots , etc , ...
#  - **tables :** Contingency table , frequency table , etc , ...
#
# >For example, suppose we have a set of raw data that shows the test scores of 500 students at a particular school.
#   We can  calculate the average test score and generate the distribution of test scores.
# Using descriptive statistics, we could find the average score and create a graph that helps us visualize the distribution of scores.
# This allows us to understand the test scores of the students much more easily compared to just staring at the raw data.**
#
# ### <u>6 - Inferential Statistics
#  - **The process of using sample statistics to make conclusions about population parameters is known as inferential statistics. In other words, data from a sample are used to make an inference about a population.**
#
#
# >For example, we might be interested in understanding the political preferences of people in Lebanon (**population = 6 millions**) ,it would take too long and be too expensive to actually survey every individual. Thus, we would instead take a sample of 1,000 lebanese citizen, and use the results of the survey to draw inferences about the population as a whole.
# ![population-sample.png](attachment:population-sample.png)

# %% [markdown]
# ### <u>7 - Data Types
#
# - **Categorical Data (variable) :** Names or labels (i.e., categories) with no logical order or with a logical order but inconsistent differences between groups (e.g., rankings), also known as qualitative.
#
# - **Quantitative Data (variable) :** Numerical values with magnitudes that can be placed in a meaningful order with consistent intervals, also known as numerical.
# ![DataTypes.png](attachment:DataTypes.png)

# %% [markdown]
# # <center><font size=10, color="blue"><u>Introduction to Python

# %% [markdown]
# ![mqdefault.jpg](attachment:mqdefault.jpg)

# %% [markdown]
# -  **Python is a popular programming language. It was created by Guido van Rossum, and released in 1991.**
# -  **Python can be used to handle big data and perform complex mathematics.**
# -  **Python can be used on a server to create web applications.**
# -  **Python works on different platforms (Windows, Mac, Linux, Raspberry Pi, etc).**
# -  **Python has a simple syntax similar to the English language.**

# %% [markdown]
# ### <u>1 - Python Indentation
# - Indentation refers to the spaces at the beginning of a code line.
#
# - The indentation in Python is very important.
#
# - Python uses indentation to indicate a block of code.
# --------------

# %% [markdown]
# - Indentation = zero spaces

# %%
x = 5
x
y = 7
y
# Out:
# 7

# %% [markdown]
# - Indentation = OneTab = 4 Spaces

# %%
    x = 5
    x
    y = 7
    y
# Out:
# 7

# %% [markdown]
# - Indentation = 10 spaces

# %%
          x = 5
          x
          y = 7
          y
# Out:
# 7

# %% [markdown]
# - Different Indentation case 1

# %%
        x = 5
        x
y = 7
y
# Out:
# 7

# %% [markdown]
# - Different Indentation case 2

# %%
x = 5
    x
    y = 7
    y
# Out:
#   File "<ipython-input-197-cc00375af526>", line 2
#     x
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# - Different Indentation case 3

# %%
x = 5
x
    y = 7
    y
# Out:
#   File "<ipython-input-198-ce7a5df4910d>", line 3
#     y = 7
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ### <u>2 - Creating a Comment
# - Comments can be used to explain Python code.
# - Comments starts with a **#**, and Python will ignore them
# ----------------------------------------------------------

# %%
# كتابة رسالة ترحيب بالجميع 
print("اهلا وسهلا بكم جميعا في محاضرات بايثون ")
# Out:
# اهلا وسهلا بكم جميعا في محاضرات بايثون

# %%
x = 5
x # print the value of x
# Out:
# 5

# %%
# Indentation Error 
     a = 2
b = 3
b
# Out:
#   File "<ipython-input-216-e45058037744>", line 2
#     a = 2
#     ^
# IndentationError: unexpected indent

# %%
     # No Error Indentation 
     a = 2
b = 3
b
# Out:
# 3

# %% [markdown]
# ### <u>3 - Python Variable
# - The variable is a container for storing data values.
# - A variable is created the moment you first assign a value to it and no need to declare it before.
# - A variable can have a short name (like x and y) or a more descriptive name (age, carname, total_volume)
# - A variable name must start with a letter or the underscore character
# - A variable name **cannot** start with a **number**
# - A variable name can only contain **alpha-numeric characters and underscores** (A-z, 0-9, and _ )
# - Variable names are case-sensitive (**weight**, **Weight** and **WEIGHT** are three different variables)
# - we can get the data type of a variable with the  **``` type()```** function.
#
# -----------------------------------------------------------------------------------

# %%
# Create a variable called "x" and assign to it the value 10 
x = 10
print(x)
# Out:
# 10

# %%
type(x)
# Out:
# int

# %%
# Change the value 
x = 15
x
# Out:
# 15

# %%
# Change the type :
x = "laptop"
print(x)
# Out:
# laptop

# %%
type(x)
# Out:
# str

# %%
# is there another variable type I did not mention it ? 
# هل يوجد نوع اخر من المتغيرات لم اذكرها ؟

# %%
# Case Sensitive :
X = 5
print(X)

# %%
car = "BMW"
print(car)
# Out:
# BMW

# %%
_car = "BMW"
_car
# Out:
# 'BMW'

# %%
# Error in variable name 
2car = "BMW"
# Out:
#   File "<ipython-input-221-097d5773f71f>", line 1
#     2car = "BMW"
#      ^
# SyntaxError: invalid syntax

# %%
car_2 = "BMW"
car_2
# Out:
# 'BMW'

# %%
# Assign values to multiple variables in one line
a , b , c = 5 , 7.5 , "Audi"
print(a) 
print(b) 
print(c)
# Out:
# 5
# 7.5
# Audi

# %%
# Assign the same value to multiple variables in one line:
a = b = c = "Lenovo"
print(a)
print(b)
print(c)
# Out:
# Lenovo
# Lenovo
# Lenovo

# %% [markdown]
# ### <u>4 - Output Variables
# - The Python **```print()```** function is often used to output variables.

# %%
x = "I Like Python"
print(x)
# Out:
# i like python

# %% [markdown]
# -  In the **```print()```** function, we can output multiple variables, separated by a **comma**

# %%
# String type variables :
x = "I"
y = "Like"
z = "Python"
print(x,y,z)
# Out:
# I Like Python

# %%
# Numeric type variables : 
a = 5
b = 10 
c = 15
print(a,b,c)
# Out:
# 5 10 15

# %%
# String and Numeric Variables 
m = "London"
p = 25
print(m,p)
# Out:
# London 25

# %% [markdown]
# - We can also use the **```+```** operator to output multiple variables

# %%
# String type variables :
x = "I"
y = "Like"
z = "Python"
print(x + y + z)
# Out:
# ILikePython

# %%
# Rewrite the same code used in the previous cell using "-" operator  :

# %%
# Numeric type variables : 
a = 5
b = 10 
c = 15
print(a+b+c)
# Out:
# 30

# %%
# Rewrite the same code used in the previous cell using "-" operator :

# %% [markdown]
# ### <u>5 - Practices

# %%
# Create a variable named Course and assign the value Python to it.

# %%
# Create a variable named age and assign the value 50 to it.

# %%
# Display the sum of 10 + 25, using two variables: x and y.(replace the ??)
?? = 10
y = 25
print(x ?? y)

# %%
# Create a variable called z, assign x + y to it, and display the result.
x = 15
y = 10
??= x + y
print(??)

# %%
# Remove the illegal characters in the variable name.
2my-preferred_course = "machine learning"

# %%
# Insert the correct syntax to assign the same value to all three variables in one code line.
x ?? y ?? z ?? "I like the red aplles"

# %% [markdown]
# ### <u>6 - Built-in Data Types
#
# ![python-data-types.png](attachment:python-data-types.png)

# %% [markdown]
# ### <u>7 - Integers
# - Int, or integer, is a whole number, positive or negative, without decimals, of unlimited length.
# - Default is Decimal (Base 10 )

# %%
a = 2
b = 10

# %%
a
# Out:
# 2

# %%
type(a)
# Out:
# int

# %%
b
# Out:
# 10

# %%
type(b)
# Out:
# int

# %% [markdown]
# - For addition we use the operator : **```+```**

# %%
a+b
# Out:
# 12

# %% [markdown]
# - For subtraction we use the operator : **```-```**

# %%
a-b
# Out:
# -8

# %% [markdown]
# - For multiplication we can use the operator : **```*```**

# %%
a*b
# Out:
# 20

# %% [markdown]
# - For power of a number we can use the operator : ```**```

# %%
b**a
# Out:
# 100

# %% [markdown]
# - For division we can use the operator : **```/```**

# %%
b/a
# Out:
# 5.0

# %%
# Convert : Decimal --> Binary 
b = 10 
bin(b)
# Out:
# '0b1010'

# %%
hex(b)
# Out:
# '0xa'

# %%
# Convert binary to decimal : 
c = 0b101
c
# Out:
# 5

# %%
number = '1235'

# %%
number
# Out:
# '1235'

# %%
number + b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-7688b6a38002> in <module>
# ----> 1 number + b
#
# TypeError: can only concatenate str (not "int") to str

# %%
number_2 = int(number)

# %%
number_2
# Out:
# 1235

# %%
number_2 + b
# Out:
# 1245

# %% [markdown]
# ###   <u>8 - Floats
# - Float, or **floating point number** is a number, positive or negative, with a decimal point
# - Division result wil be a float
# - Can be defined using scientific notation with an **```e```** or **```E```** to indicate the power of 10.

# %%
a = 4.2

# %%
print(a)
# Out:
# 4.2

# %%
type(a)
# Out:
# float

# %%
c , d = 10 , 4

# %%
print(c)
print(d)
# Out:
# 10
# 4

# %%
f = -5.2
print(f)
# Out:
# -5.2

# %%
# Addition : 
a+c
# Out:
# 14.2

# %%
# Division : 
e = c/d
e
# Out:
# 2.5

# %%
d = 5

# %%
f = c/d
f
# Out:
# 2.0

# %% [markdown]
# - To get the Quotient of the division  we use : **```//```**

# %%
c = 17
d = 4
g = c//d
g
# Out:
# 4

# %% [markdown]
# - To get the Remainder of the division  we use : **```%```**

# %%
# Remainder of Devision :
c%d
# Out:
# 1

# %%
# Scientific notation : 
i = 5e3
i
# Out:
# 5000.0

# %%
i = 5E3
i
# Out:
# 5000.0

# %%
k = 7e-2
k
# Out:
# 0.07

# %%
k = 7E-2
k
# Out:
# 0.07

# %%
t = 2*5e2
t
# Out:
# 1000.0

# %%
f = -5.23
f
# Out:
# -5.23

# %% [markdown]
# ### <u>9 - Complex Numbers
#  - Expressed in the form **```a+bj```**
#  - Consist of real and imaginary part
#  - **j** is the square of **-1**

# %%
a = 2+3j
a
# Out:
# (2+3j)

# %%
type(a)
# Out:
# complex

# %%
a.imag
# Out:
# 3.0

# %%
a.real
# Out:
# 2.0

# %%
a.conjugate()
# Out:
# (2-3j)

# %%
b = 3+5j

# %%
a+b
# Out:
# (5+8j)

# %%
a-b
# Out:
# (-1-2j)

# %%
a*b
# Out:
# (-9+19j)

# %%
a.imag
# Out:
# 3.0

# %% [markdown]
# ### <u>10 - Type Conversion
#  - we can convert from one type to another with the **```int()```**, **```float()```**, and **```complex()```** methods
#  - we **cannot convert complex** numbers into another number type.

# %%
x = 8   # int
y = 5.3  # float
z = 2+3j   # complex

#convert from int to float:
a = float(x)

#convert from float to int:
b = int(y)

#convert from int to complex:
c = complex(x)

print(a)
print(b)
print(c)

print(type(a))
print(type(b))
print(type(c))
# Out:
# 8.0
# 5
# (8+0j)
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %%
# Insert the correct syntax to convert x into a floating point number
x = 5
x = ??

# %%
# Insert the correct syntax to convert x into an integer.
x = 5.5
x = ??

# %%
# Insert the correct syntax to convert x into a complex number.
x = 5
x = ??

# %% [markdown]
# ### <u>11 - String
# - A string is a series of characters.
# - Anything inside quotes is a string.
# - We can use either single quotes **```''```**or double quotes **```""```**.

# %%
salam = " Hello how are you "
salam
# Out:
# ' Hello how are you '

# %%
salam = 'Hello how are you'
salam
# Out:
# 'Hello how are you'

# %%
# a string contains a single quote 
season = "it's winter time"
season
# Out:
# "it's winter time"

# %%
#  Using the backslash (\), to escape the quotes,
truth = "the lion is not cute, it\'s dangerous"
truth
# Out:
# "the lion is not cute, it's dangerous"

# %%
# We can assign a multiline string to a variable by using three quotes:
data_analysis = '''
-python
-machine learning 
-deep learning 
'''
print(data_analysis)
# Out:
# -python
# -machine learning
# -deep learning

# %% [markdown]
# #### <u>11.1 -  Strings with the f-strings
# - to use the value of the variable **x** inside the **y** string variable, place the letter **f** before the opening quotation mark and put the brace around the variable **x**

# %%
x = 5
order = f'i need {x} green apples'
order
# Out:
# 'i need 5 green apples'

# %%
a = 4
b = 8
c = a+b
print(f"the sum of the two numbers {a} and {b} is {c}")
# Out:
# the sum of the two numbers 4 and 8 is 12

# %% [markdown]
# #### <u>11.2 - Concatenating Python strings

# %%
x = "Good"
y = "Morning"
print(x+y)
# Out:
# GoodMorning

# %%
# add space 
print(x + " " + y + ".")
# Out:
# Good Morning.

# %% [markdown]
# #### <u>11.3 - Accessing string elements
# - Since a string is a sequence of characters, we can access its elements using an index. The first character in the string has an index of **zero**.
# - Using a negative index, Python returns the character starting from the end of the string.

# %%
str = "Python String"
print(str[0]) 
print(str[1])
# Out:
# P
# y

# %%
print(str[-1]) 
print(str[-3])
# Out:
# g
# i

# %% [markdown]
# #### <u>11.4 - String Length
# ``` python
# To get the length of a string, we can use the len() function.
# ```

# %%
str = "Python  String"
str_len = len(str)
print(str_len)
# Out:
# 14

# %% [markdown]
# #### <u>11.5 - Slicing strings
# - Slicing allows us to get a substring from a string. For example:

# %%
# The str[0:2] returns a substring that includes the character from the index 0 (included) to 2 (excluded).
str = "Python String"
len(str)
# Out:
# 13

# %%
print(str[0:2])
# Out:
# Py

# %%
print(str[7:10])
# Out:
# Str

# %%
print(str[7:])
# Out:
# String

# %% [markdown]
# #### <u>11.6 - Looping Through a String
# - Since a string is a sequence of characters, we can loop through the characters in a string, with a for loop.

# %%
for x in "house":
  print(x)
# Out:
# h
# o
# u
# s
# e

# %%
for y in "12345" :
    print(y)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# #### <u>11.7 -  Check String
# - To check if a certain phrase or character is present in a string.

# %%
best = "Messi is the best player in the world"
best
# Out:
# 'Messi is the best player in the world'

# %%
# Index of the leteer "i" in "best"
best.index("i")
# Out:
# 4

# %%
# Count number of "i" in "best"
best.count("i")
# Out:
# 3

# %%
# Checking if "best" contains the letter "z"
print("z" in best)
# Out:
# False

# %%
# Checking if "best" contains the word "Messi"
"Messi" in best
# Out:
# True

# %%
# Checking if "best" contains the word "messi"
"messi" in best # case sensitive
# Out:
# False

# %%
# Return True if the string is a whitespace string, False otherwise.
best.isspace()
# Out:
# False

# %%
g = ' '
g.isspace()
# Out:
# True

# %% [markdown]
# #### <u>11.8 -  Python strings are immutable
# - Python strings are immutable. It means that we cannot change a character in the string.

# %%
# Error 
str = "Python String"
str[0] = 'J'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-342-8fddaa3a8360> in <module>
#       1 # Error ☹
#       2 str = "Python String"
# ----> 3 str[0] = 'J'
#
# TypeError: 'str' object does not support item assignment

# %%
# When want to modify a string, we need to create a new one from the existing string. 
aya_said = "Hello Guys"
hiba_said = aya_said[0:6] + "Samir"
hiba_said
# Out:
# 'Hello Samir'
